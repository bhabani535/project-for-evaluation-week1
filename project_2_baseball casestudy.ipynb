# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('baseball1.csv')
df.head()
# Out:
#    Wins  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0    95   724     5575  1497      300       42       139    383         973
# 1    83   696     5467  1349      277       44       156    439        1264
# 2    81   669     5439  1395      303       29       141    533        1157
# 3    76   622     5533  1381      260       27       136    404        1231
# 4    74   689     5605  1515      289       49       151    455        1259
#
#    Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average (ERA)  \
# 0           104           641          601                      3.73
# 1            70           700          653                      4.07
# 2            86           640          584                      3.67
# 3            68           701          643                      3.98
# 4            83           803          746                      4.64
#
#    Complete Game  Shutouts  Saves  Errors
# 0              2         8     56      88
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df.dtypes
# Out:
# Wins                          int64
# Runs                          int64
# At Bats                       int64
# Hits                          int64
# Doubles                       int64
# Triples                       int64
# Homeruns                      int64
# Walks                         int64
# Strikeouts                    int64
# Stolen Bases                  int64
# Runs Allowed                  int64
# Earned Runs                   int64
# Earned Run Average (ERA)    float64
# Complete Game                 int64
# Shutouts                      int64
# Saves                         int64
# Errors                        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Wins', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
#        'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
#        'Earned Run Average (ERA)', 'Complete Game', 'Shutouts', 'Saves',
#        'Errors'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Wins                      30 non-null     int64
#  1   Runs                      30 non-null     int64
#  2   At Bats                   30 non-null     int64
#  3   Hits                      30 non-null     int64
#  4   Doubles                   30 non-null     int64
#  5   Triples                   30 non-null     int64
#  6   Homeruns                  30 non-null     int64
#  7   Walks                     30 non-null     int64
#  8   Strikeouts                30 non-null     int64
#  9   Stolen Bases              30 non-null     int64
#  10  Runs Allowed              30 non-null     int64
#  11  Earned Runs               30 non-null     int64
#  12  Earned Run Average (ERA)  30 non-null     float64
#  13  Complete Game             30 non-null     int64
# ...

# %%
df.describe()
# Out:
#              Wins        Runs      At Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %%
# outliers are present cause the gap between 75% and max is more in some features-->At Bats,Runs,Strikeouts,Runs Allowed,
#High standard deviation are present in most features-->

# %%
df.isnull().sum()
# Out:
# Wins                        0
# Runs                        0
# At Bats                     0
# Hits                        0
# Doubles                     0
# Triples                     0
# Homeruns                    0
# Walks                       0
# Strikeouts                  0
# Stolen Bases                0
# Runs Allowed                0
# Earned Runs                 0
# Earned Run Average (ERA)    0
# Complete Game               0
# Shutouts                    0
# Saves                       0
# Errors                      0
# dtype: int64

# %% [markdown]
# so theres no missing values

# %%
#check for duplicated data
duplicate=df.duplicated()
print(duplicate.sum())
df[duplicate]
# Out:
# 0
# Empty DataFrame
# Columns: [Wins, Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Complete Game, Shutouts, Saves, Errors]
# Index: []

# %% [markdown]
# We know that there's no missing or duplicate values

# %%
df.corr()
# Out:
#                               Wins      Runs   At Bats      Hits   Doubles  \
# Wins                      1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                      0.430751  1.000000  0.319464  0.482856  0.560084
# At Bats                  -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                      0.037612  0.482856  0.739122  1.000000  0.566847
# Doubles                   0.427797  0.560084  0.453370  0.566847  1.000000
# Triples                  -0.251118 -0.070072  0.435422  0.478694  0.220490
# Homeruns                  0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walks                     0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strikeouts                0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Stolen Bases             -0.157234  0.081367  0.372618  0.413444  0.195027
# Runs Allowed             -0.812952 -0.041623  0.316010  0.224324 -0.218160
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(),cmap='Blues',annot=True)

# %%
#we can see wins feature is correlated positively with---->Runs,Doubles,Homeruns,Walks,Shutouts,Saves
#                                      negatively with---->Runs Allowed,Earned Runs,Earned Run Average(ERA)

# %%
collist=df.columns.values
ncol=16
nrows=16

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
#so outliers are present
#and Errors has more no of outliers

# %%
plt.scatter(df['Wins'],df['Doubles'])
plt.show()

# %%
sns.pairplot(df)

# %%
#As we already know that Wins is the Target variable so lets focus on that feature and its relation with other features

# %% [raw]
# we can see Wins feature is correlated moderatly positive with---->Runs,Doubles,Homeruns,Walks,Shutouts,Saves
# we can see Wins feature is correlated highly negative with---->Runs Allowed,Earned Runs,Earned Run Average(ERA)

# %%
sns.barplot(x = 'Wins', y = 'Doubles', data =df)

# %%
sns.barplot(x = 'Wins', y = 'Triples', data =df)

# %%
sns.barplot(x = 'Wins', y = 'Runs', data =df)

# %%
sns.lineplot(x = 'Wins', y = 'Walks', data =df)

# %%
sns.lineplot(x = 'Wins', y = 'Runs', data =df)

# %%
#more you  score runs,triple,double higher the chances to win

# %%
sns.lineplot(x = 'Wins', y = 'Runs Allowed', data =df)

# %%
sns.lineplot(x = 'Wins', y = 'Earned Runs', data =df)

# %%
sns.lineplot(x = 'Wins', y = 'Earned Run Average (ERA)', data =df)

# %%
#the higher (Runs Allowed,Earned Runs,Earned Run Average(ERA) )
#the lower the chances to win

# %%
#checking skewness
df.skew()
# Out:
# Wins                        0.047089
# Runs                        1.200786
# At Bats                     0.183437
# Hits                        0.670254
# Doubles                    -0.230650
# Triples                     0.129502
# Homeruns                    0.516441
# Walks                       0.158498
# Strikeouts                 -0.156065
# Stolen Bases                0.479893
# Runs Allowed                0.045734
# Earned Runs                 0.058710
# Earned Run Average (ERA)    0.053331
# Complete Game               0.736845
# Shutouts                    0.565790
# Saves                       0.657524
# Errors                      0.890132
# dtype: float64

# %%
#Treating using log
import numpy as np
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.sqrt(df[col])

# %%
df.skew()
# Out:
# Wins                        0.047089
# Runs                        0.968676
# At Bats                     0.183437
# Hits                        0.649567
# Doubles                    -0.230650
# Triples                     0.129502
# Homeruns                    0.516441
# Walks                       0.158498
# Strikeouts                 -0.156065
# Stolen Bases                0.479893
# Runs Allowed                0.045734
# Earned Runs                 0.058710
# Earned Run Average (ERA)    0.053331
# Complete Game              -0.311476
# Shutouts                   -0.061761
# Saves                       0.410288
# Errors                      0.763487
# dtype: float64

# %%
#Skewness is definitely reduced

# %%
#Now cleansing the DATA

# %%
#Removing outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
dfnew=df[(z<3).all(axis=1)]

# %%
df.shape,dfnew.shape
# Out:
# ((30, 17), (29, 17))

# %%
#so outliers have been taken care of 
#one row removed

# %% [markdown]
# # Machine learning process

# %%
y=dfnew['Wins']
dfnew.drop(['Wins'], axis=1, inplace=True)
x=(dfnew)
print(x.shape)
print(y.shape)
# Out:
# (29, 16)
# (29,)

# %%
x
# Out:
#          Runs  At Bats       Hits  Doubles  Triples  Homeruns  Walks  \
# 0   26.907248     5575  38.691084      300       42       139    383
# 1   26.381812     5467  36.728735      277       44       156    439
# 2   25.865034     5439  37.349699      303       29       141    533
# 3   24.939928     5533  37.161808      260       27       136    404
# 4   26.248809     5605  38.923001      289       49       151    455
# 6   27.640550     5567  37.376463      272       19       212    554
# 7   26.702060     5485  37.013511      246       20       217    418
# 8   25.377155     5485  37.188708      278       32       167    436
# 9   27.349589     5640  38.665230      294       33       161    478
# 10  27.404379     5511  37.669616      279       32       172    503
# 11  27.000000     5459  36.918830      278       26       230    486
# 12  25.709920     5417  36.482873      243       21       176    435
# 13  25.612497     5544  37.134889      262       22       198    478
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: Wins, dtype: int64

# %%
#so i think y is in format we dont need to resize it

# %%
#i think all values are numerical so no need of label encoding

# %%
#for knn classifier we used to scale the data and for KNN regressor should we need to scale the data?
##there's no harm in scaling the data so lets do it
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler().fit(x)
newx=scaler.transform(x)
print(newx)
# Out:
# [[ 0.95651645  0.83008422  1.73108753  1.55653766  1.01084549 -0.76586314
#   -1.53635899 -2.72762331  0.9059529  -0.66451353 -0.51114812 -0.51138828
#   -0.25354897 -0.77743601  1.60263096 -0.45432526]
#  [ 0.34416795 -0.70283074 -0.94430524  0.20117132  1.20891656 -0.18138864
#   -0.49502051  0.12189552 -0.58531515  0.15463823  0.23216082  0.23895226
#   -0.25354897  0.24747497  0.25562074 -0.60761852]
#  [-0.25808975 -1.10025314 -0.097707    1.73332457 -0.2766165  -0.69710144
#    1.25294051 -0.9258657   0.11645805 -0.67839746 -0.75415297 -0.64380131
#    2.02046293 -0.23916196 -0.68939326 -1.15869812]
#  [-1.33621796  0.23395062 -0.35386977 -0.8006212  -0.47468758 -0.8690057
#   -1.14585706 -0.20124579 -0.6730368   0.16852216  0.08921679  0.04033271
#    1.21854679 -0.50080556 -0.83128957  0.50227443]
#  [ 0.18916563  1.25589393  2.047274    0.90831897  1.70409425 -0.35329291
#   -0.19749523  0.07293472 -0.01512442  1.58468284  1.56154027  1.4968761
# ...

# %%
#Machine learning Model selection

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#lets make a function which evaluates the model using cross_val_score
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    c_scores=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print(c_scores)

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression
lnr=LinearRegression()
final_r_state=maxr2_score(lnr,x,y)
# Out:
# r2 score corresponding to  42  is  0.3602399776494438
# r2 score corresponding to  43  is  -4.016080799506869
# r2 score corresponding to  44  is  0.291493121650377
# r2 score corresponding to  45  is  0.13557366868816545
# r2 score corresponding to  46  is  0.7547953060230345
# r2 score corresponding to  47  is  -0.07301666500683646
# r2 score corresponding to  48  is  -0.35824645359797946
# r2 score corresponding to  49  is  -0.4259817704805844
# r2 score corresponding to  50  is  0.7859017408354414
# r2 score corresponding to  51  is  0.6282006763152749
# r2 score corresponding to  52  is  0.3715130965444067
# r2 score corresponding to  53  is  0.3132035513705169
# r2 score corresponding to  54  is  -0.12675203667642498
# r2 score corresponding to  55  is  0.7321586402612467
# r2 score corresponding to  56  is  0.6629549998547009
# r2 score corresponding to  57  is  0.5597365385682095
# r2 score corresponding to  58  is  0.6009957897613372
# ...

# %%
#lets check for overfitting or underfitting for this model
print("Linear regression\n\n")
model_evaluation(lnr,newx,y)
# Out:
# Linear regression
#
#
# Mean r2 score for regressor:  -0.06843618500244206
# standard deviation in r2 score for regressor:  0.6089633207585462
# [ 0.68626146 -0.51376938  0.65092867 -0.44197534 -0.72362634]

# %%
from sklearn import linear_model
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state =73,test_size=0.20)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np
print("r2 score is: ",r2_score(y_test,y_pred))
print("RMSE is : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is:  0.8581238412073223
# RMSE is :  4.342546039617013

# %%
#ummm

# %% [markdown]
# # Decision Tree

# %%
regr=DecisionTreeRegressor()
final_r_state=maxr2_score(regr,newx,y)
# Out:
# r2 score corresponding to  42  is  -0.05536332179930792
# r2 score corresponding to  43  is  -0.7813012575177691
# r2 score corresponding to  44  is  0.3433333333333334
# r2 score corresponding to  45  is  -0.40794223826714804
# r2 score corresponding to  46  is  0.5641845591594334
# r2 score corresponding to  47  is  0.832306338028169
# r2 score corresponding to  48  is  0.42122830440587444
# r2 score corresponding to  49  is  -0.8910003585514519
# r2 score corresponding to  50  is  -1.352272727272727
# r2 score corresponding to  51  is  -0.19396984924623117
# r2 score corresponding to  52  is  -0.20143454871488342
# r2 score corresponding to  53  is  0.26718995290423864
# r2 score corresponding to  54  is  -0.5800711743772242
# r2 score corresponding to  55  is  0.4371439422711736
# r2 score corresponding to  56  is  -0.6307554760840413
# r2 score corresponding to  57  is  0.5602836879432624
# r2 score corresponding to  58  is  -0.33061480552070255
# ...

# %%
print("Decision Tree regression\n\n")
model_evaluation(regr,newx,y)
# Out:
# Decision Tree regression
#
#
# Mean r2 score for regressor:  -2.6220409132854097
# standard deviation in r2 score for regressor:  4.0363984945787506
# [-1.63522727e+00 -1.06184211e+01 -2.92764534e-03 -2.70491803e-01
#  -5.83136792e-01]

# %% [markdown]
# # KN regressor

# %%
#using grid search for optimal value of k in knn
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
parameters = {'n_neighbors':range(2,10)}
knr = KNeighborsRegressor()
clf = GridSearchCV(knr, parameters, cv=5)
clf.fit(newx,y)
clf.best_params_
# Out:
# {'n_neighbors': 4}

# %%
knr=KNeighborsRegressor(n_neighbors=4)
final_r_state=maxr2_score(knr,newx,y)
# Out:
# r2 score corresponding to  42  is  0.4944852941176471
# r2 score corresponding to  43  is  0.43555221432476765
# r2 score corresponding to  44  is  0.8235416666666666
# r2 score corresponding to  45  is  0.2581227436823105
# r2 score corresponding to  46  is  0.5006281407035176
# r2 score corresponding to  47  is  0.6346555897887325
# r2 score corresponding to  48  is  0.5756842456608812
# r2 score corresponding to  49  is  -0.5244711366081032
# r2 score corresponding to  50  is  0.23180725524475532
# r2 score corresponding to  51  is  0.6634422110552765
# r2 score corresponding to  52  is  0.6924686192468619
# r2 score corresponding to  53  is  0.33112244897959187
# r2 score corresponding to  54  is  0.541258896797153
# r2 score corresponding to  55  is  0.36735662742119257
# r2 score corresponding to  56  is  0.5711890925346446
# r2 score corresponding to  57  is  0.817080378250591
# r2 score corresponding to  58  is  0.3131665621079047
# ...

# %%
print("Knn regression\n\n")
model_evaluation(knr,newx,y)
# Out:
# Knn regression
#
#
# Mean r2 score for regressor:  0.0179690815594322
# standard deviation in r2 score for regressor:  0.7661433377129562
# [-0.23600852 -1.36677632  0.49085111  0.44334016  0.75843897]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 44,test_size=0.20)
from sklearn.neighbors import KNeighborsRegressor
regr = KNeighborsRegressor(n_neighbors=4)
regr.fit(x_train,y_train)
y_pred = regr.predict(x_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred) )
print("Mean squared error: %.2f" % mean_squared_error(y_test,y_pred))
# Out:
# RMSE is:  5.919600211726014
# r2_score is:  0.2991666666666667
# Mean squared error: 35.04

# %% [markdown]
# # RandomForestRegressor

# %%
#lets use ensemble model Random forests
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,50,100,150,200,250,500]}
clf = GridSearchCV(rfr, parameters, cv=5,scoring="r2")
clf.fit(newx,y)#for random forest scaling is required
clf.best_params_
# Out:
# {'n_estimators': 250}

# %%
rfr=RandomForestRegressor(n_estimators=250)
maxr2_score(rfr,newx,y)
# Out:
# r2 score corresponding to  42  is  0.5565515570934261
# r2 score corresponding to  43  is  0.21569243958447326
# r2 score corresponding to  44  is  0.6030457066666668
# r2 score corresponding to  45  is  0.015708101083032
# r2 score corresponding to  46  is  0.7711596381909546
# r2 score corresponding to  47  is  0.7782732535211268
# r2 score corresponding to  48  is  0.7236044966622164
# r2 score corresponding to  49  is  -0.5764975776263899
# r2 score corresponding to  50  is  0.22456914685314644
# r2 score corresponding to  51  is  0.5268855638190952
# r2 score corresponding to  52  is  0.41449232755528953
# r2 score corresponding to  53  is  0.686513974254317
# r2 score corresponding to  54  is  0.6888119003558723
# r2 score corresponding to  55  is  0.5868421785036082
# r2 score corresponding to  56  is  0.19490447563701363
# r2 score corresponding to  57  is  0.6092338723404256
# r2 score corresponding to  58  is  0.15882631869510677
# ...

# %%
print("Random Forest\n\n")
model_evaluation(rfr,newx,y)
# Out:
# Random Forest
#
#
# Mean r2 score for regressor:  -0.13501461891978753
# standard deviation in r2 score for regressor:  1.0236544852767102
# [-1.58029607  0.51569633  0.65955588]

# %% [markdown]
# # Support vector regression

# %%
#Lets use SVM
from sklearn.svm import SVR
svc=SVR()
parameters={"kernel":["linear", "poly", "rbf"],"C":[0.001,0.01,0.1,1,10]}
clf = GridSearchCV(svc, parameters, cv=5,scoring="r2")
clf.fit(x,y)
clf.best_params_
# Out:
# {'C': 0.1, 'kernel': 'linear'}

# %%
from sklearn.svm import SVR
svr=SVR(kernel="linear",C=0.1)
maxr2_score(svr,newx,y)
# Out:
# r2 score corresponding to  42  is  0.5314993669308335
# r2 score corresponding to  43  is  0.5192635706887496
# r2 score corresponding to  44  is  0.7337832904725581
# r2 score corresponding to  45  is  0.488782880283385
# r2 score corresponding to  46  is  0.771148095587918
# r2 score corresponding to  47  is  0.6597652177423916
# r2 score corresponding to  48  is  0.4600895055134967
# r2 score corresponding to  49  is  -0.7746949717018445
# r2 score corresponding to  50  is  0.3536695722372428
# r2 score corresponding to  51  is  0.5286940015737577
# r2 score corresponding to  52  is  0.37208143607971644
# r2 score corresponding to  53  is  0.5318835222170171
# r2 score corresponding to  54  is  0.6909641990209693
# r2 score corresponding to  55  is  0.4892103033968719
# r2 score corresponding to  56  is  0.5942886736633023
# r2 score corresponding to  57  is  0.6563189783883246
# r2 score corresponding to  58  is  0.41786664661135264
# ...

# %%
model_evaluation(svr,newx,y)
# Out:
# Mean r2 score for regressor:  0.28058744738925623
# standard deviation in r2 score for regressor:  0.2650271445692021
# [-0.08968147  0.41537536  0.51606846]

# %%
#lets use svc as our final model
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 82,test_size=0.20)
svr = SVR(kernel="linear",C=0.1)
svr.fit(x_train,y_train)
y_pred = svr.predict(x_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2_score is: ",r2_score(y_test,y_pred) )
print("Mean squared error: %.2f" % mean_squared_error(y_test,y_pred))
# Out:
# RMSE is:  2.674024135090647
# r2_score is:  0.9022352515375229
# Mean squared error: 7.15

# %%
 import joblib
joblib.dump(svr,'baseball.obj')
# Out:
# ['baseball.obj']

# %%
#so i chose this model as r2 score is high and rmse is low
#And also i think there is less no of rows(means data) so less training testing data
